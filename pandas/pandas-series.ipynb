# %%
print("Hello world")
# Out:
# Hello world

# %%
# pandas is a open source libary written in python
# numpy is also do the same thing but it is written in c

#importing the statements in python

import pandas as pd #pd is a alias for pandas
import numpy as np # np is a allias for numpy

# %%
pip install openpyxl

# %%
dic = {
    "name" : ['a','b','c'],
    "age" : [10,20,30]
}

# %%
print(dic)
# Out:
# {'name': ['a', 'b', 'c'], 'age': [10, 20, 30]}

# %%
df = pd.DataFrame(dic)
print(df)
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
df.to_csv('Demo',index = False)

# %%
# reading the csv file
df = pd.read_csv('Demo.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 2
#       1 # reading the csv file
# ----> 2 df = pd.read_csv('Demo.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
print(df.to_string())
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
print(df.to_string(index=False))
# Out:
# name  age
#    a   10
#    b   20
#    c   30

# %%
df.head()
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
df.head(1)
# Out:
#   name  age
# 0    a   10

# %%
df.tail(1)
# Out:
#   name  age
# 2    c   30

# %%
# playing with the json (javascript object notation) file.
dfjson = pd.read_json('data.json')
print(dfjson.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.describe()
# Out:
#         age
# count   3.0
# mean   20.0
# std    10.0
# min    10.0
# 25%    15.0
# 50%    20.0
# 75%    25.0
# max    30.0

# %%
df[0][0] = 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df[0][0] = 0
#
# ...

# %%
df
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
df[0]['name'] = 'Null'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df[0]['name'] = 'Null'
#
# ...

# %%
df
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
df.dropna()
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.5 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.5 kB 435.7 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.5 kB 544.7 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.5 kB 544.7 kB/s eta 0:00:01
#      -------------------------- --------- 122.9/165.5 kB 602.4 kB/s eta 0:00:01
#      ------------------------------- ---- 143.4/165.5 kB 607.9 kB/s eta 0:00:01
#      ------------------------------------ 165.5/165.5 kB 522.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.0 MB 653.6 kB/s eta 0:00:13
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <Axes: >

# %%
dfjson.plot()
# Out:
# <Axes: >

# %%
plt.show()

# %%
dfjson.plot()
plt.show()

# %%
dfjson.plot(kind = 'scatter' , x = 'Duration' , y = 'Calories')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
dfjson.plot(kind = 'box' , x = 'Duration' , y = 'Calories')
# Out:
# <Axes: >

# %%
dfjson.plot(kind = 'pie' , x = 'Duration' , y = 'Calories')
# Out:
# <Axes: ylabel='Calories'>
